# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('geocoder_data.csv')

# %%
df['latitude'] = 0.0
df['longitude'] = 0.0

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0           0
# 1                1           1
# 2                2           2
# 3                3           3
# 4                4           5
# ...            ...         ...
# 1206          1206        1342
# 1207          1207        1343
# 1208          1208        1344
# 1209          1209        1345
# 1210          1210        1346
#
#                                                  url  \
# 0     https://spb.cian.ru/sale/commercial/300074346/
# 1     https://spb.cian.ru/sale/commercial/300073799/
# 2     https://spb.cian.ru/sale/commercial/300073275/
# 3     https://spb.cian.ru/sale/commercial/300070206/
# 4     https://spb.cian.ru/sale/commercial/300069782/
# ...                                              ...
# 1206  https://spb.cian.ru/sale/commercial/295288773/
# 1207  https://spb.cian.ru/sale/commercial/295288770/
# 1208  https://spb.cian.ru/sale/commercial/295280790/
# 1209  https://spb.cian.ru/sale/commercial/295279637/
# 1210  https://spb.cian.ru/sale/commercial/295278414/
#
#                                  seller_url                            title  \
# 0     https://www.cian.ru/company/83887466/  Свободное назначение, 131,63 м²
# 1      https://spb.cian.ru/company/12477946   Свободное назначение, 145,1 м²
# 2      https://spb.cian.ru/company/59606612    Свободное назначение, 73,5 м²
# 3                                       NaN     Свободное назначение, 682 м²
# 4      https://spb.cian.ru/company/74333292        Торговая площадь, 33,9 м²
# ...                                     ...                              ...
# 1206      https://spb.cian.ru/company/28717   Свободное назначение, 1 555 м²
# 1207      https://spb.cian.ru/company/28717   Свободное назначение, 1 555 м²
# 1208                                    NaN      Свободное назначение, 45 м²
# 1209                                    NaN        Арендный бизнес, 274,4 м²
# 1210   https://spb.cian.ru/company/12477923       Торговая площадь, 728,2 м²
#
#       squares   full_price  price_per_square    floor  free  ...  \
# 0      131.63   41000000.0          311480.0   1 из 2     0  ...
# 1      145.10   37000000.0          254997.0   1 из 5     0  ...
# 2       73.50   26000000.0          353742.0   1 из 7     0  ...
# 3      682.00   71500000.0          104839.0   1 из 2     0  ...
# 4       33.90    6441000.0          190000.0   1 из 9     0  ...
# ...       ...          ...               ...      ...   ...  ...
# 1206  1555.00  123000000.0           79100.0   3 из 3     0  ...
# 1207  1555.00  132175000.0           85000.0   3 из 3     0  ...
# 1208    45.00    3800000.0           84445.0  -1 из 6     0  ...
# 1209   274.40   43000000.0          156706.0        1     1  ...
# 1210   728.20   82836000.0          113755.0   1 из 4     0  ...
#
#                                     street house_number  \
# 0                       ул. Восстановления           19
# 1                  7-я Красноармейская ул.            5
# 2                 11-я Красноармейская ул.           11
# 3                              ул. Коммуны          9к1
# 4                               ул. Лагоды            5
# ...                                    ...          ...
# 1206                   Большая Озерная ул.          70Б
# 1207                   Большая Озерная ул.          70Б
# 1208  просп. Большой Петроградской стороны         28/1
# 1209                       просп. Королева         64к1
# 1210                  Комендантский просп.      4к2литА
#
#                                             description  \
# 0     Продажа помещения свободного назначения в бизн...
# 1     ID 6024 - пoжaлуйстa, coобщитe этот номер мeне...
# 2     Код объекта: 1053925.\nПродается помещение пло...
# 3     Новое здание Бизнес-Центра и профессиональный ...
# 4     ВНИМАНИЕ! ЗАКРЫТАЯ ПРОДАЖА - ВСЕ ПОДРОБНОСТИ П...
# ...                                                 ...
# 1206  ЗВОНИТЕ! Всегда работаем с агентами и посредни...
# 1207  Трехэтажное нежилое здание,возле Суздальских о...
# 1208  Подвальное помещение без ремонта на 1ой линии ...
# 1209  Продается арендный бизнес - помещение, располо...
# 1210  Общая площадь Комплекса 22 000 кв.м\nАрендопри...
#
#                                                sub_near  \
# 0     [['Проспект Ветеранов', '25 мин.'], ['Ленински...
# 1                                                    []
# 2     [['Балтийская', '10 мин.'], ['Фрунзенская', '1...
# 3                  [['Проспект Большевиков', '9 мин.']]
# 4     [['Ладожская', '6 мин.'], ['Новочеркасская', '...
# ...                                                 ...
# 1206  [['Проспект Просвещения', '6 мин.'], ['Удельна...
# 1207  [['Проспект Просвещения', '6 мин.'], ['Удельна...
# 1208  [['Спортивная', '8 мин.'], ['Чкаловская', '8 м...
# 1209  [['Комендантский проспект', '6 мин.'], ['Удель...
# 1210  [['Комендантский проспект', '13 мин.'], ['Стар...
#
#                                            highway_near current_floor  \
# 0     [['Нарва шоссе', '25 км от КАД'], ['Киевское ш...           1.0
# 1                                                    []           1.0
# 2                                                    []           1.0
# 3                                                    []           1.0
# 4                                                    []           1.0
# ...                                                 ...           ...
# 1206                                                 []           3.0
# 1207                                                 []           3.0
# 1208                                                 []           NaN
# 1209                                                 []           1.0
# 1210                                                 []           1.0
#
#      max_floor                                            address   latitude  \
# 0          2.0  Санкт-Петербург, р-н Красносельский, мкр. Крас...  30.082621
# 1          5.0  Санкт-Петербург, р-н Адмиралтейский, Измайловс...  30.316138
# 2          7.0  Санкт-Петербург, р-н Адмиралтейский, Измайловс...  30.301127
# 3          2.0  Санкт-Петербург, р-н Красногвардейский, Порохо...  30.506167
# 4          9.0  Санкт-Петербург, р-н Красногвардейский, Порохо...  30.449978
# ...        ...                                                ...        ...
# 1206       3.0  Санкт-Петербург, р-н Выборгский, Шувалово-Озер...   0.000000
# 1207       3.0  Санкт-Петербург, р-н Выборгский, Шувалово-Озер...   0.000000
# 1208       NaN  Санкт-Петербург, р-н Петроградский, Петровский...   0.000000
# 1209       1.0  Санкт-Петербург, р-н Приморский, Коломяги, про...   0.000000
# 1210       4.0  Санкт-Петербург, р-н Приморский, Озеро Долгое,...   0.000000
#
#       longitude
# 0     59.724677
# 1     59.911854
# 2     59.912368
# 3     59.941687
# 4     59.956836
# ...         ...
# 1206   0.000000
# 1207   0.000000
# 1208   0.000000
# 1209   0.000000
# 1210   0.000000
#
# [1211 rows x 23 columns]

# %%
import requests

def get_coordinates(address):
    api_key = "ce2524a7-073a-41e9-8f8d-47caa1182bdc"
    url = f"https://geocode-maps.yandex.ru/1.x/?apikey={api_key}&geocode={address}&format=json"
    response = requests.get(url)
    data = response.json()
    if response.status_code == 200:
        found = int(data['response']['GeoObjectCollection']['metaDataProperty']['GeocoderResponseMetaData']['found'])
        if found > 0:
            coords_str = data['response']['GeoObjectCollection']['featureMember'][0]['GeoObject']['Point']['pos']
            coordinates = tuple(map(float, coords_str.split()))
            return coordinates
        else:
            print("Объекты по заданному адресу не найдены.")
            return None
    else:
        print("Ошибка при получении координат.")
        return None

# %%
for i in range(901,1211):
    address = df.iloc[i,-3]
    coordinates = get_coordinates(address)
    df.at[i, 'latitude'], df.at[i, 'longitude'] = coordinates

# %%
df.tail()
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 1206          1206        1342
# 1207          1207        1343
# 1208          1208        1344
# 1209          1209        1345
# 1210          1210        1346
#
#                                                  url  \
# 1206  https://spb.cian.ru/sale/commercial/295288773/
# 1207  https://spb.cian.ru/sale/commercial/295288770/
# 1208  https://spb.cian.ru/sale/commercial/295280790/
# 1209  https://spb.cian.ru/sale/commercial/295279637/
# 1210  https://spb.cian.ru/sale/commercial/295278414/
#
#                                 seller_url                           title  \
# 1206     https://spb.cian.ru/company/28717  Свободное назначение, 1 555 м²
# 1207     https://spb.cian.ru/company/28717  Свободное назначение, 1 555 м²
# 1208                                   NaN     Свободное назначение, 45 м²
# 1209                                   NaN       Арендный бизнес, 274,4 м²
# 1210  https://spb.cian.ru/company/12477923      Торговая площадь, 728,2 м²
#
#       squares   full_price  price_per_square    floor  free  ...  \
# 1206   1555.0  123000000.0           79100.0   3 из 3     0  ...
# 1207   1555.0  132175000.0           85000.0   3 из 3     0  ...
# 1208     45.0    3800000.0           84445.0  -1 из 6     0  ...
# 1209    274.4   43000000.0          156706.0        1     1  ...
# 1210    728.2   82836000.0          113755.0   1 из 4     0  ...
#
#                                     street house_number  \
# 1206                   Большая Озерная ул.          70Б
# 1207                   Большая Озерная ул.          70Б
# 1208  просп. Большой Петроградской стороны         28/1
# 1209                       просп. Королева         64к1
# 1210                  Комендантский просп.      4к2литА
#
#                                             description  \
# 1206  ЗВОНИТЕ! Всегда работаем с агентами и посредни...
# 1207  Трехэтажное нежилое здание,возле Суздальских о...
# 1208  Подвальное помещение без ремонта на 1ой линии ...
# 1209  Продается арендный бизнес - помещение, располо...
# 1210  Общая площадь Комплекса 22 000 кв.м\nАрендопри...
#
#                                                sub_near highway_near  \
# 1206  [['Проспект Просвещения', '6 мин.'], ['Удельна...           []
# 1207  [['Проспект Просвещения', '6 мин.'], ['Удельна...           []
# 1208  [['Спортивная', '8 мин.'], ['Чкаловская', '8 м...           []
# 1209  [['Комендантский проспект', '6 мин.'], ['Удель...           []
# 1210  [['Комендантский проспект', '13 мин.'], ['Стар...           []
#
#      current_floor max_floor  \
# 1206           3.0       3.0
# 1207           3.0       3.0
# 1208           NaN       NaN
# 1209           1.0       1.0
# 1210           1.0       4.0
#
#                                                 address   latitude  longitude
# 1206  Санкт-Петербург, р-н Выборгский, Шувалово-Озер...  30.302187  60.040204
# 1207  Санкт-Петербург, р-н Выборгский, Шувалово-Озер...  30.302187  60.040204
# 1208  Санкт-Петербург, р-н Петроградский, Петровский...  30.297156  59.956899
# 1209  Санкт-Петербург, р-н Приморский, Коломяги, про...  30.237427  60.033976
# 1210  Санкт-Петербург, р-н Приморский, Озеро Долгое,...  30.266146  60.002018
#
# [5 rows x 23 columns]

# %%
df.to_csv('geocoder_data.csv', encoding='utf-8')
