# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('DONEDONE_DATA.csv',index_col=0)

# %%
df
# Out:
#       price_per_square   full_price  rent_per_month  squares  max_floor  \
# 0             252200.4    7067312.0         60000.0     20.0        1.0
# 1             342781.0    9481312.0         60000.0     20.0        1.0
# 2             332892.0    8550000.0         60000.0     20.0        1.0
# 3             351785.8   11040000.0         80000.0     20.0        1.0
# 4             332892.0    8550000.0         20000.0     20.0        2.0
# ...                ...          ...             ...      ...        ...
# 1573          238096.0   70000000.0        330514.0    294.0       10.0
# 1574          250000.0   74500000.0        370248.8    298.0        4.0
# 1575          384616.0  115000000.0        367800.0    299.0        8.0
# 1576          200000.0   60000000.0        326200.0    300.0        3.0
# 1577          298334.0   89500000.0        367800.0    300.0        6.0
#
#        latitude  longitude  metro_250m  metro_500m  metro_1km  parkings_1km  \
# ...

# %%
df.corr()
# Out:
#                     price_per_square  full_price  rent_per_month   squares  \
# price_per_square            1.000000    0.383881       -0.141728 -0.198218
# full_price                  0.383881    1.000000        0.593443  0.779164
# rent_per_month             -0.141728    0.593443        1.000000  0.746596
# squares                    -0.198218    0.779164        0.746596  1.000000
# max_floor                   0.151943    0.005294       -0.035801 -0.090316
# latitude                   -0.195878   -0.145898       -0.048599 -0.043210
# longitude                   0.053218    0.066338        0.078068  0.049112
# metro_250m                  0.063045    0.031840        0.031016 -0.001373
# metro_500m                  0.099986    0.078175        0.010017  0.014355
# metro_1km                   0.133209    0.082358       -0.008771 -0.005763
# parkings_1km                0.084859    0.079375        0.048924  0.051949
# ...

# %%
df.columns
# Out:
# Index(['price_per_square', 'full_price', 'rent_per_month', 'squares',
#        'max_floor', 'latitude', 'longitude', 'metro_250m', 'metro_500m',
#        'metro_1km', 'parkings_1km', 'rent_per_square_m', 'distance_to_center',
#        'population', 'mean_distr_pps', 'pop_per_park'],
#       dtype='object')

# %%
data = df.copy()

# %%
data
# Out:
#       price_per_square   full_price  rent_per_month  squares  max_floor  \
# 0             252200.4    7067312.0         60000.0     20.0        1.0
# 1             342781.0    9481312.0         60000.0     20.0        1.0
# 2             332892.0    8550000.0         60000.0     20.0        1.0
# 3             351785.8   11040000.0         80000.0     20.0        1.0
# 4             332892.0    8550000.0         20000.0     20.0        2.0
# ...                ...          ...             ...      ...        ...
# 1573          238096.0   70000000.0        330514.0    294.0       10.0
# 1574          250000.0   74500000.0        370248.8    298.0        4.0
# 1575          384616.0  115000000.0        367800.0    299.0        8.0
# 1576          200000.0   60000000.0        326200.0    300.0        3.0
# 1577          298334.0   89500000.0        367800.0    300.0        6.0
#
#        latitude  longitude  metro_250m  metro_500m  metro_1km  parkings_1km  \
# ...

# %%
data.corr()
# Out:
#                     price_per_square  full_price  rent_per_month   squares  \
# price_per_square            1.000000    0.383881       -0.141728 -0.198218
# full_price                  0.383881    1.000000        0.593443  0.779164
# rent_per_month             -0.141728    0.593443        1.000000  0.746596
# squares                    -0.198218    0.779164        0.746596  1.000000
# max_floor                   0.151943    0.005294       -0.035801 -0.090316
# latitude                   -0.195878   -0.145898       -0.048599 -0.043210
# longitude                   0.053218    0.066338        0.078068  0.049112
# metro_250m                  0.063045    0.031840        0.031016 -0.001373
# metro_500m                  0.099986    0.078175        0.010017  0.014355
# metro_1km                   0.133209    0.082358       -0.008771 -0.005763
# parkings_1km                0.084859    0.079375        0.048924  0.051949
# ...

# %%
sns.histplot(data=data,x='price_per_square',bins = 50)
# Out:
# c:\Users\xfd20\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\xfd20\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_square', ylabel='Count'>

# %%
plt.figure(figsize=(12,7))
sns.regplot(data=data,x='distance_to_center',y='price_per_square')
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.regplot(data=data,x='squares',y='price_per_square')
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.regplot(data=data,x='parkings_1km',y='price_per_square')
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.regplot(data=data,x='max_floor',y='price_per_square')
plt.show()

# %%
data
# Out:
#       price_per_square   full_price  rent_per_month  squares  max_floor  \
# 0             252200.4    7067312.0         60000.0     20.0        1.0
# 1             342781.0    9481312.0         60000.0     20.0        1.0
# 2             332892.0    8550000.0         60000.0     20.0        1.0
# 3             351785.8   11040000.0         80000.0     20.0        1.0
# 4             332892.0    8550000.0         20000.0     20.0        2.0
# ...                ...          ...             ...      ...        ...
# 1573          238096.0   70000000.0        330514.0    294.0       10.0
# 1574          250000.0   74500000.0        370248.8    298.0        4.0
# 1575          384616.0  115000000.0        367800.0    299.0        8.0
# 1576          200000.0   60000000.0        326200.0    300.0        3.0
# 1577          298334.0   89500000.0        367800.0    300.0        6.0
#
#        latitude  longitude  metro_250m  metro_500m  metro_1km  parkings_1km  \
# ...

# %%
data.columns
# Out:
# Index(['price_per_square', 'full_price', 'rent_per_month', 'squares',
#        'max_floor', 'latitude', 'longitude', 'metro_250m', 'metro_500m',
#        'metro_1km', 'parkings_1km', 'rent_per_square_m', 'distance_to_center',
#        'population', 'mean_distr_pps', 'pop_per_park'],
#       dtype='object')

# %%
data.corr(method='spearman')
# Out:
#                     price_per_square  full_price  rent_per_month   squares  \
# price_per_square            1.000000    0.358309       -0.153421 -0.199121
# full_price                  0.358309    1.000000        0.663442  0.805930
# rent_per_month             -0.153421    0.663442        1.000000  0.820025
# squares                    -0.199121    0.805930        0.820025  1.000000
# max_floor                   0.144573    0.064512        0.006665 -0.036772
# latitude                   -0.227595   -0.168300       -0.070931 -0.060960
# longitude                   0.047649    0.080676        0.078325  0.056213
# metro_250m                  0.067165    0.028189        0.015835 -0.003423
# metro_500m                  0.079962    0.048370       -0.007927  0.009698
# metro_1km                   0.168443    0.065692       -0.039737 -0.023417
# parkings_1km                0.100803    0.110513        0.055919  0.059259
# ...

# %%
data = data[['price_per_square', 'rent_per_month', 'squares',
       'max_floor', 'latitude', 'longitude', 'metro_250m', 'metro_500m',
       'metro_1km', 'parkings_1km', 'rent_per_square_m', 'distance_to_center',
       'population', 'mean_distr_pps', 'pop_per_park']]

# %%
# histograms
plt.figure(figsize=(20,7))
data.hist(sharex=False, sharey=False, xlabelsize=1, ylabelsize=1)
plt.show()

# %%
data.to_csv('starting_to_work.csv',encoding='utf-8')

# %%
data.columns
# Out:
# Index(['price_per_square', 'rent_per_month', 'squares', 'max_floor',
#        'latitude', 'longitude', 'metro_250m', 'metro_500m', 'metro_1km',
#        'parkings_1km', 'rent_per_square_m', 'distance_to_center', 'population',
#        'mean_distr_pps', 'pop_per_park'],
#       dtype='object')

# %%
plt.figure(figsize=(20,7))
sns.heatmap(data.corr(method='kendall'),annot=True,fmt=".2g")
plt.show()

# %%
from scipy.stats import kendalltau

# %%
kendalltau(data['price_per_square'],data['longitude'])
# Out:
# SignificanceResult(statistic=0.03006442500276587, pvalue=0.07383343435419897)

# %%
for i in data.columns:
    print(f"{i}:{kendalltau(data['price_per_square'], data[i])}")
# Out:
# price_per_square:SignificanceResult(statistic=1.0, pvalue=0.0)
# rent_per_month:SignificanceResult(statistic=-0.10166843221669027, pvalue=1.5184835747617714e-09)
# squares:SignificanceResult(statistic=-0.1345648261358557, pvalue=1.2469305859263337e-15)
# max_floor:SignificanceResult(statistic=0.0969508397716097, pvalue=2.3439397468774648e-08)
# latitude:SignificanceResult(statistic=-0.14713412532957168, pvalue=2.160198640454504e-18)
# longitude:SignificanceResult(statistic=0.03006442500276587, pvalue=0.07383343435419897)
# metro_250m:SignificanceResult(statistic=0.05482973631026898, pvalue=0.007479801148051103)
# metro_500m:SignificanceResult(statistic=0.06419882070413326, pvalue=0.0013862746331217372)
# metro_1km:SignificanceResult(statistic=0.1305563960365624, pvalue=6.893475332991766e-12)
# parkings_1km:SignificanceResult(statistic=0.06715748365419498, pvalue=7.257946332356938e-05)
# rent_per_square_m:SignificanceResult(statistic=0.039384910804234514, pvalue=0.0192462803966023)
# ...

# %%
for i in data.columns:
    tau, pvalue = kendalltau(data['price_per_square'], data[i])
    if pvalue >= 0.05:
        print(f"{i}: tau={tau}, pvalue={pvalue}")
# Out:
# longitude: tau=0.03006442500276587, pvalue=0.07383343435419897

# %%
data.columns
# Out:
# Index(['price_per_square', 'rent_per_month', 'squares', 'max_floor',
#        'latitude', 'longitude', 'metro_250m', 'metro_500m', 'metro_1km',
#        'parkings_1km', 'rent_per_square_m', 'distance_to_center', 'population',
#        'mean_distr_pps', 'pop_per_park'],
#       dtype='object')

# %%
data.rename(columns={'latitude':'longitudes','longitude':'lattitude'},inplace=True)

# %%
data.rename(columns={'lattitude':'latitude','longitudes':'longitude'},inplace=True)

# %%
X = data[[ 'squares', 'max_floor', 'metro_1km','latitude', 'longitude',
       'parkings_1km', 'distance_to_center',
       'mean_distr_pps']]
y = data['price_per_square']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 999)

# %%
from sklearn.ensemble import RandomForestRegressor

rfc = RandomForestRegressor(n_estimators=100)
rfc.fit(X_train, y_train)
display(rfc.score(X_train, y_train))
# Out:
# 0.9174562382075111

# %%
predictions1 = rfc.predict(X_train)
#Calculate the root mean squared error
rmse = np.sqrt(mean_squared_error(y_train, predictions1))
print(rmse)
print(mean_absolute_error(y_train, predictions1))
print(mean_absolute_percentage_error(y_train, predictions1))
# Out:
# 23097.802614595093
# 16678.55111938721
# 0.08624310594595021

# %%
predictions2 = rfc.predict(X_test)
#Calculate the root mean squared error
display(rfc.score(X_test, y_test))
rmse = np.sqrt(mean_squared_error(y_test, predictions2))
print(rmse)
print(mean_absolute_error(y_test, predictions2))
print(mean_absolute_percentage_error(y_test, predictions2))
# Out:
# 0.43722024591249087
# 58450.47172013554
# 43128.06020042193
# 0.2166268677997037
